# %% [markdown]
# DATATYPES

# %%
##INTEGER
age = 20
print(age,type(age))
# Out:
# 20 <class 'int'>

# %%
##FLOAT
height = 5.11
print(height,type(height))
# Out:
# 5.11 <class 'float'>

# %%
##STRING
Name="Aayush"
print(Name,type(Name))
# Out:
# Aayush <class 'str'>

# %%
#BOOLEAN
is_true = True
type(is_true)
# Out:
# bool

# %%
A=10
B=10

type(A==B)
# Out:
# bool

# %%
#Errors

#Typecasting
result = "Hello" + str(10)
print(result)
# Out:
# Hello10
